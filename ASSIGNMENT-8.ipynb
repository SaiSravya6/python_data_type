# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4,2.56789,9,87.9999,40,'hyderabad']
k
# Out:
# [4, 2.56789, 9, 87.9999, 40, 'hyderabad']

# %%
pd.Series(k)
# Out:
# 0            4
# 1      2.56789
# 2            9
# 3      87.9999
# 4           40
# 5    hyderabad
# dtype: object

# %%
a=np.random.randint(20,50,15)
a
# Out:
# array([35, 37, 45, 37, 23, 29, 44, 29, 48, 32, 48, 31, 25, 42, 28])

# %%
a.ndim
# Out:
# 2

# %%
pd.Series(a)
# Out:
# 0     35
# 1     37
# 2     45
# 3     37
# 4     23
# 5     29
# 6     44
# 7     29
# 8     48
# 9     32
# 10    48
# 11    31
# 12    25
# 13    42
# 14    28
# dtype: int64

# %%
a=np.random.randint(20,50,(5,4))
a
# Out:
# array([[41, 29, 48, 38],
#        [45, 32, 40, 38],
#        [49, 21, 40, 32],
#        [38, 45, 22, 38],
#        [46, 44, 39, 31]])

# %%
b=np.random.randint(100,200,(6,5))
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (6, 5)

# %%
b
# Out:
# array([[143, 128, 160, 101, 113],
#        [158, 133, 191, 181, 122],
#        [124, 168, 162, 118, 110],
#        [101, 166, 159, 138, 178],
#        [122, 198, 107, 131, 105],
#        [181, 193, 101, 199, 121]])

# %%
np.random.seed(34)
b=np.random.randint(100,200,60)
b
# Out:
# array([133, 185, 168, 135, 169, 111, 178, 129, 118, 129, 189, 129, 120,
#        196, 162, 105, 120, 151, 119, 185, 121, 163, 172, 142, 184, 172,
#        177, 136, 102, 137, 198, 158, 142, 175, 134, 158, 162, 138, 188,
#        166, 170, 142, 196, 143, 185, 131, 184, 189, 162, 184, 190, 157,
#        177, 144, 119, 193, 138, 123, 109, 113])

# %%
pd.Series(b)
# Out:
# 0     133
# 1     185
# 2     168
# 3     135
# 4     169
# 5     111
# 6     178
# 7     129
# 8     118
# 9     129
# 10    189
# 11    129
# 12    120
# 13    196
# 14    162
# 15    105
# 16    120
# 17    151
# 18    119
# 19    185
# 20    121
# 21    163
# 22    172
# 23    142
# 24    184
# 25    172
# 26    177
# 27    136
# 28    102
# 29    137
# 30    198
# 31    158
# 32    142
# 33    175
# 34    134
# 35    158
# 36    162
# 37    138
# 38    188
# 39    166
# 40    170
# 41    142
# 42    196
# 43    143
# 44    185
# 45    131
# 46    184
# 47    189
# 48    162
# 49    184
# 50    190
# 51    157
# 52    177
# 53    144
# 54    119
# 55    193
# 56    138
# 57    123
# 58    109
# 59    113
# dtype: int64

# %%
df=pd.DataFrame(b)
df
# Out:
#       0
# 0   133
# 1   185
# 2   168
# 3   135
# 4   169
# 5   111
# 6   178
# 7   129
# 8   118
# 9   129
# 10  189
# 11  129
# 12  120
# 13  196
# 14  162
# 15  105
# 16  120
# 17  151
# 18  119
# 19  185
# 20  121
# 21  163
# 22  172
# 23  142
# 24  184
# 25  172
# 26  177
# 27  136
# 28  102
# 29  137
# 30  198
# 31  158
# 32  142
# 33  175
# 34  134
# 35  158
# 36  162
# 37  138
# 38  188
# 39  166
# 40  170
# 41  142
# 42  196
# 43  143
# 44  185
# 45  131
# 46  184
# 47  189
# 48  162
# 49  184
# 50  190
# 51  157
# 52  177
# 53  144
# 54  119
# 55  193
# 56  138
# 57  123
# 58  109
# 59  113

# %%
np.random.seed(34)
b=np.random.randint(100,200,(6,5))
b
# Out:
# array([[133, 185, 168, 135, 169],
#        [111, 178, 129, 118, 129],
#        [189, 129, 120, 196, 162],
#        [105, 120, 151, 119, 185],
#        [121, 163, 172, 142, 184],
#        [172, 177, 136, 102, 137]])

# %%
pd.Series(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1968fc85138f> in <cell line: 0>()
# ----> 1 pd.Series(b)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     582                 data = data.copy()
#     583         else:
# --> 584             data = sanitize_array(data, index, dtype, copy)
#     585
#     586             manager = _get_option("mode.data_manager", silent=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     657                 subarr = maybe_infer_to_datetimelike(subarr)
#     658
# --> 659     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     660
#     661     if isinstance(subarr, np.ndarray):
#
# ...

# %%
df=pd.DataFrame(b,columns=['Roll','name','adds','age','country'],index=[182,183,184,185,186,187])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-7c3075fe3f3f> in <cell line: 0>()
# ----> 1 df=pd.DataFrame(b,columns=['Roll','name','adds','age','country'],index=[182,183,184,185,186,187])
#       2 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     825                 )
#     826             else:
# --> 827                 mgr = ndarray_to_mgr(
#     828                     data,
#     829                     index,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     334     )
#     335
# --> 336     _check_values_indices_shape_match(values, index, columns)
#     337
#     338     if typ == "array":
#
# ...

# %%
df.iloc[0]
# Out:
# 0    133
# Name: 0, dtype: int64

# %%
df.loc[133]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: 133 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-114d7236ce05> in <cell line: 0>()
# ----> 1 df.loc[133]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
# ...

# %%
df.iloc[0,0]
# Out:
# 133

# %%
df.loc[185,'Roll']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-673af8940fee> in <cell line: 0>()
# ----> 1 df.loc[185,'Roll']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
# -> 1183                 return self.obj._get_value(*key, takeable=self._takeable)
#    1184             return self._getitem_tuple(key)
#    1185         else:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    4212             return series._values[index]
#    4213
# -> 4214         series = self._get_item_cache(col)
#    4215         engine = self.index._engine
#    4216
#
# ...

# %%
df.iloc[185,'Roll','name','age']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-49-98841ebf2b46> in <cell line: 0>()
# ----> 1 df.iloc[185,'Roll','name','age']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
#    1692             return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[[182,186,187]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-90c3e612967a> in <cell line: 0>()
# ----> 1 df.loc[[182,186,187]]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1418                     raise ValueError("Cannot index with multidimensional key")
#    1419
# -> 1420                 return self._getitem_iterable(key, axis=axis)
#    1421
#    1422             # nested tuple slicing
#
# ...

# %%
df.loc[[133,185,168],['adds','name','Roll']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-722a28a4f88f> in <cell line: 0>()
# ----> 1 df.loc[[133,185,168],['adds','name','Roll']]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1373         # ugly hack for GH #836
#    1374         if self._multi_take_opportunity(tup):
# -> 1375             return self._multi_take(tup)
#    1376
#    1377         return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.load_dataset('diamonds')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.iloc[0.0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-a2180691068a> in <cell line: 0>()
# ----> 1 df.iloc[0.0:3]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1727
#    1728         if isinstance(key, slice):
# -> 1729             return self._get_slice_axis(key, axis=axis)
#    1730
#    1731         if is_iterator(key):
#
# ...

# %%
df.iloc[0[0,1,2]]
# Out:
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <ipython-input-48-2ed47e106b66>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   df.iloc[0[0,1,2]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-2ed47e106b66> in <cell line: 0>()
# ----> 1 df.iloc[0[0,1,2]]
#
# TypeError: 'int' object is not subscriptable
